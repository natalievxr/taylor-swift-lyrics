# %%
# Import spacy
import spacy

# Install English language model
# !spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 14.6 MB/s eta 0:00:0000:0100:01
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
# Import os to upload documents and metadata
import os

# Load spaCy visualizer
from spacy import displacy

# Import pandas DataFrame packages
import pandas as pd
pd.options.mode.chained_assignment = None  # default='warn'

# Import graphing package
import plotly.express as px

# %%
# Create empty lists for file names and contents
texts = []
file_names = []

# Iterate through each file in the folder
for _file_name in os.listdir('txt_files'):
# Look for only text files
    if _file_name.endswith('.txt'):
    # Append contents of each text file to text list
        texts.append(open('txt_files' + '/' + _file_name, 'r', encoding='utf-8').read())
        # Append name of each file to file name list
        file_names.append(_file_name)

# %%
# Create dictionary object associating each file name with its text
d = {'Filename':file_names,'Text':texts}

# %%
# Turn dictionary into a dataframe
lyrics = pd.DataFrame(d)

# %%
lyrics.head()
# Out:
#                Filename                                               Text
# 0  tisthedamnseason.txt  ’tis the damn season Lyrics[Verse 1]\nIf I wan...
# 1          evermore.txt  evermore Lyrics[Verse 1: Taylor Swift]\nGray N...
# 2         happiness.txt  happiness Lyrics[Verse 1]\nHoney, when I'm abo...
# 3        tolerateit.txt  tolerate it Lyrics[Verse 1]\nI sit and watch y...
# 4            willow.txt  willow Lyrics[Verse 1]\nI'm like the water whe...

# %%
# Remove extra spaces from papers


lyrics['Text'] = paper_df['Text'].str.replace(r'\s+', ' ', regex=True).str.strip()
lyrics.head()
# Out:
#                Filename                                               Text
# 0  tisthedamnseason.txt  ’tis the damn season Lyrics[Verse 1] If I want...
# 1          evermore.txt  evermore Lyrics[Verse 1: Taylor Swift] Gray No...
# 2         happiness.txt  happiness Lyrics[Verse 1] Honey, when I'm abov...
# 3        tolerateit.txt  tolerate it Lyrics[Verse 1] I sit and watch yo...
# 4            willow.txt  willow Lyrics[Verse 1] I'm like the water when...

# %%
# Remove .txt from title of each paper
lyrics['Filename'] = lyrics['Filename'].str.replace('.txt', '', regex=True)

# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
# Load nlp pipeline
nlp = spacy.load('en_core_web_sm')

# Check what functions it performs
print(nlp.pipe_names)
# Out:
# ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']

# %%
#Define example sentence
sentence = "This is 'an' example? sentence"

# Call the nlp model on the sentence
doc = nlp(sentence)

# %%
# Define a function that runs the nlp pipeline on any given input text
def process_text(text):
    return nlp(text)

# %%
# Apply the function to the "Text" column, so that the nlp pipeline is called on each student essay
lyrics['Doc'] = lyrics['Text'].apply(process_text)

# %%
# Define a function to retrieve tokens from a doc object
def get_token(doc):
    return [(token.text) for token in doc]

# %%
# Run the token retrieval function on the doc objects in the dataframe
lyrics['Tokens'] = lyrics['Doc'].apply(get_token)
lyrics.head()
# Out:
#            Filename                                               Text  \
# 0  tisthedamnseason  ’tis the damn season Lyrics[Verse 1] If I want...
# 1          evermore  evermore Lyrics[Verse 1: Taylor Swift] Gray No...
# 2         happiness  happiness Lyrics[Verse 1] Honey, when I'm abov...
# 3        tolerateit  tolerate it Lyrics[Verse 1] I sit and watch yo...
# 4            willow  willow Lyrics[Verse 1] I'm like the water when...
#
#                                                  Doc  \
# 0  (’, tis, the, damn, season, Lyrics[Verse, 1, ]...
# 1  (evermore, Lyrics[Verse, 1, :, Taylor, Swift, ...
# 2  (happiness, Lyrics[Verse, 1, ], Honey, ,, when...
# 3  (tolerate, it, Lyrics[Verse, 1, ], I, sit, and...
# 4  (willow, Lyrics[Verse, 1, ], I, 'm, like, the,...
#
#                                               Tokens
# 0  [’, tis, the, damn, season, Lyrics[Verse, 1, ]...
# 1  [evermore, Lyrics[Verse, 1, :, Taylor, Swift, ...
# 2  [happiness, Lyrics[Verse, 1, ], Honey, ,, when...
# 3  [tolerate, it, Lyrics[Verse, 1, ], I, sit, and...
# 4  [willow, Lyrics[Verse, 1, ], I, 'm, like, the,...

# %%
tokens = lyrics[['Text', 'Tokens']].copy()
tokens.head()
# Out:
#                                                 Text  \
# 0  ’tis the damn season Lyrics[Verse 1] If I want...
# 1  evermore Lyrics[Verse 1: Taylor Swift] Gray No...
# 2  happiness Lyrics[Verse 1] Honey, when I'm abov...
# 3  tolerate it Lyrics[Verse 1] I sit and watch yo...
# 4  willow Lyrics[Verse 1] I'm like the water when...
#
#                                               Tokens
# 0  [’, tis, the, damn, season, Lyrics[Verse, 1, ]...
# 1  [evermore, Lyrics[Verse, 1, :, Taylor, Swift, ...
# 2  [happiness, Lyrics[Verse, 1, ], Honey, ,, when...
# 3  [tolerate, it, Lyrics[Verse, 1, ], I, sit, and...
# 4  [willow, Lyrics[Verse, 1, ], I, 'm, like, the,...

# %%
# Define a function to retrieve lemmas from a doc object
def get_lemma(doc):
    return [(token.lemma_) for token in doc]

# Run the lemma retrieval function on the doc objects in the dataframe
lyrics['Lemmas'] = lyrics['Doc'].apply(get_lemma)

# %%
print(f'"Write" appears in the text tokens column ' + str(lyrics['Tokens'].apply(lambda x: x.count('write')).sum()) + ' times.')
print(f'"Write" appears in the lemmas column ' + str(lyrics['Lemmas'].apply(lambda x: x.count('write')).sum()) + ' times.')
# Out:
# "Write" appears in the text tokens column 5 times.
# "Write" appears in the lemmas column 5 times.

# %%
# Define a function to retrieve lemmas from a doc object
def get_pos(doc):
    #Return the coarse- and fine-grained part of speech text for each token in the doc
    return [(token.pos_, token.tag_) for token in doc]

# Define a function to retrieve parts of speech from a doc object
lyrics['POS'] = lyrics['Doc'].apply(get_pos)

# %%
# Create a list of part of speech tags
list(lyrics['POS'])
# Out:
# [[('PUNCT', '``'),
#   ('VERB', 'VBP'),
#   ('DET', 'DT'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NN'),
#   ('X', 'LS'),
#   ('PUNCT', '-RRB-'),
#   ('SCONJ', 'IN'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('PRON', 'WP'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBD'),
#   ('VERB', 'VBG'),
#   ('ADP', 'IN'),
#   ('SCONJ', 'IN'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBD'),
#   ('VERB', 'VBN'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('AUX', 'VB'),
#   ('VERB', 'VBN'),
#   ('PRON', 'PRP'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBZ'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('ADJ', 'JJ'),
#   ('PUNCT', ','),
#   ('VERB', 'VBP'),
#   ('ADP', 'RP'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NN'),
#   ('CCONJ', 'CC'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('PRON', 'PRP'),
#   ('SCONJ', 'WRB'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('PRON', 'PRP'),
#   ('PRON', 'EX'),
#   ('VERB', 'VBZ'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP'),
#   ('PUNCT', ','),
#   ('VERB', 'VBN'),
#   ('ADV', 'RB'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP'),
#   ('CCONJ', 'CC'),
#   ('SCONJ', 'IN'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBZ'),
#   ('DET', 'PDT'),
#   ('DET', 'DT'),
#   ('ADJ', 'JJ'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBZ'),
#   ('DET', 'DT'),
#   ('ADJ', 'JJ'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP'),
#   ('X', 'XX'),
#   ('X', 'XX'),
#   ('PUNCT', '-RRB-'),
#   ('ADV', 'RB'),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('ADV', 'RB'),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('PUNCT', '``'),
#   ('NOUN', 'NN'),
#   ('PUNCT', "''"),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADV', 'RB'),
#   ('DET', 'DT'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('VERB', 'VB'),
#   ('PRON', 'DT'),
#   ('ADP', 'RP'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', "''"),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NNS'),
#   ('PART', 'POS'),
#   ('NOUN', 'NN'),
#   ('CCONJ', 'CC'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PART', 'RB'),
#   ('VERB', 'VBN'),
#   ('NOUN', 'NNS'),
#   ('ADV', 'RB'),
#   ('ADJ', 'JJ'),
#   ('ADV', 'RB'),
#   ('CCONJ', 'CC'),
#   ('PRON', 'PRP'),
#   ('ADV', 'RB'),
#   ('VERB', 'VBZ'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP'),
#   ('CCONJ', 'CC'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('X', 'XX'),
#   ('NOUN', 'NN'),
#   ('NUM', 'CD'),
#   ('PUNCT', '-RRB-'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBZ'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('ADV', 'RB'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('CCONJ', 'CC'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NN'),
#   ('PRON', 'WDT'),
#   ('VERB', 'VBD'),
#   ('PART', 'TO'),
#   ('AUX', 'VB'),
#   ('PRON', 'PRP'),
#   ('DET', 'DT'),
#   ('NOUN', 'NNS'),
#   ('ADJ', 'JJ'),
#   ('ADP', 'IN'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('VERB', 'VB'),
#   ('PUNCT', ','),
#   ('CCONJ', 'CC'),
#   ('ADV', 'RB'),
#   ('ADV', 'RB'),
#   ('ADV', 'RB'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('PRON', 'PRP'),
#   ('ADV', 'RB'),
#   ('PUNCT', ','),
#   ('VERB', 'VB'),
#   ('SCONJ', 'WRB'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VB'),
#   ('CCONJ', 'CC'),
#   ('SCONJ', 'IN'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBZ'),
#   ('ADJ', 'JJ'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBZ'),
#   ('ADJ', 'JJ'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP'),
#   ('X', 'XX'),
#   ('X', 'XX'),
#   ('PUNCT', '-RRB-'),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('ADV', 'RB'),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('PUNCT', '``'),
#   ('NOUN', 'NN'),
#   ('PUNCT', "''"),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADV', 'RB'),
#   ('DET', 'DT'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('VERB', 'VB'),
#   ('PRON', 'DT'),
#   ('ADP', 'RP'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', "''"),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NNS'),
#   ('PART', 'POS'),
#   ('NOUN', 'NN'),
#   ('CCONJ', 'CC'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PART', 'RB'),
#   ('VERB', 'VBN'),
#   ('NOUN', 'NNS'),
#   ('ADV', 'RB'),
#   ('ADJ', 'JJ'),
#   ('ADV', 'RB'),
#   ('PROPN', 'NNP'),
#   ('NOUN', 'NNS'),
#   ('PUNCT', ','),
#   ('ADJ', 'JJ'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NNS'),
#   ('ADV', 'RB'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('VERB', 'VBG'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('VERB', 'VBP'),
#   ('PRON', 'PRP'),
#   ('ADP', 'RP'),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('ADV', 'RB'),
#   ('VERB', 'VB'),
#   ('ADV', 'RB'),
#   ('CCONJ', 'CC'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PART', 'RB'),
#   ('VERB', 'VBN'),
#   ('NOUN', 'NNS'),
#   ('ADV', 'RB'),
#   ('ADJ', 'JJ'),
#   ('ADV', 'RB'),
#   ('CCONJ', 'CC'),
#   ('PRON', 'PRP'),
#   ('ADV', 'RB'),
#   ('VERB', 'VBZ'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP'),
#   ('CCONJ', 'CC'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('X', 'XX'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '-RRB-'),
#   ('VERB', 'VBP'),
#   ('ADP', 'IN'),
#   ('DET', 'PDT'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADV', 'RB'),
#   ('ADP', 'IN'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NNS'),
#   ('PART', 'POS'),
#   ('NOUN', 'NN'),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('PART', 'RB'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('SCONJ', 'IN'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('PART', 'RB'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('ADV', 'RB'),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('VERB', 'VB'),
#   ('ADV', 'RB'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('CCONJ', 'CC'),
#   ('DET', 'DT'),
#   ('ADV', 'RB'),
#   ('PUNCT', 'HYPH'),
#   ('VERB', 'VBN'),
#   ('NOUN', 'NNS'),
#   ('PRON', 'WP'),
#   ('AUX', 'MD'),
#   ('VERB', 'VB'),
#   ('NOUN', 'NNS'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP'),
#   ('SCONJ', 'IN'),
#   ('PRON', 'PRP'),
#   ('ADV', 'RB'),
#   ('VERB', 'VBP'),
#   ('PRON', 'PRP'),
#   ('CCONJ', 'CC'),
#   ('VERB', 'VB'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('PRON', 'WP'),
#   ('AUX', 'MD'),
#   ('VERB', 'VB'),
#   ('DET', 'WDT'),
#   ('VERB', 'VBZ'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('ADJ', 'JJ'),
#   ('PUNCT', "''"),
#   ('CCONJ', 'CC'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', "''"),
#   ('AUX', 'VBZ'),
#   ('PRON', 'PRP$'),
#   ('ADJ', 'JJ'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('DET', 'DT'),
#   ('ADJ', 'JJS'),
#   ('NOUN', 'NN'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('ADV', 'RB'),
#   ('VERB', 'VBN'),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('ADV', 'RB'),
#   ('ADV', 'RB'),
#   ('SCONJ', 'IN'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('VERB', 'VBG'),
#   ('CCONJ', 'CC'),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('AUX', 'VB'),
#   ('PRON', 'PRP$'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADV', 'RB'),
#   ('DET', 'DT'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('ADV', 'RB'),
#   ('VERB', 'VB'),
#   ('X', 'XX'),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('ADV', 'RB'),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('PUNCT', '``'),
#   ('NOUN', 'NN'),
#   ('PUNCT', "''"),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADV', 'RB'),
#   ('DET', 'DT'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('VERB', 'VB'),
#   ('PRON', 'DT'),
#   ('ADP', 'RP'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', "''"),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NNS'),
#   ('PART', 'POS'),
#   ('NOUN', 'NN'),
#   ('CCONJ', 'CC'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PART', 'RB'),
#   ('VERB', 'VBN'),
#   ('NOUN', 'NNS'),
#   ('ADV', 'RB'),
#   ('ADJ', 'JJ'),
#   ('ADV', 'RB'),
#   ('PROPN', 'NNP'),
#   ('NOUN', 'NNS'),
#   ('PUNCT', ','),
#   ('ADJ', 'JJ'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NNS'),
#   ('ADV', 'RB'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('VERB', 'VBG'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('VERB', 'VBP'),
#   ('PRON', 'PRP'),
#   ('ADP', 'RP'),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('ADV', 'RB'),
#   ('VERB', 'VB'),
#   ('ADV', 'RB'),
#   ('CCONJ', 'CC'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PART', 'RB'),
#   ('VERB', 'VBN'),
#   ('NOUN', 'NNS'),
#   ('ADV', 'RB'),
#   ('ADJ', 'JJ'),
#   ('ADV', 'RB'),
#   ('CCONJ', 'CC'),
#   ('PRON', 'PRP'),
#   ('ADV', 'RB'),
#   ('VERB', 'VBZ'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP'),
#   ('CCONJ', 'CC'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('X', 'XX'),
#   ('X', 'XX'),
#   ('PUNCT', '-RRB-'),
#   ('PRON', 'PRP'),
#   ('ADV', 'RB'),
#   ('VERB', 'VBZ'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP'),
#   ('CCONJ', 'CC'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN')],
#  [('ADV', 'RB'),
#   ('NOUN', 'NN'),
#   ('NUM', 'CD'),
#   ('PUNCT', ':'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '-RRB-'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('AUX', 'VBN'),
#   ('ADV', 'RB'),
#   ('SCONJ', 'IN'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('NOUN', 'NN'),
#   ('VERB', 'VBD'),
#   ('PRON', 'PRP'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NNS'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('VERB', 'VBG'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('SCONJ', 'WRB'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NNS'),
#   ('VERB', 'VBN'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('X', 'XX'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ':'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '-RRB-'),
#   ('CCONJ', 'CC'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBD'),
#   ('VERB', 'VBG'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('VERB', 'VBG'),
#   ('ADP', 'RP'),
#   ('DET', 'DT'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('VERB', 'VBG'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('CCONJ', 'CC'),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('PART', 'RB'),
#   ('AUX', 'VB'),
#   ('ADJ', 'JJ'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADV', 'RB'),
#   ('ADJ', 'JJ'),
#   ('SCONJ', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('AUX', 'MD'),
#   ('AUX', 'VB'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('X', 'XX'),
#   ('NOUN', 'NN'),
#   ('NUM', 'CD'),
#   ('PUNCT', ':'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '-RRB-'),
#   ('INTJ', 'UH'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('VERB', 'VBG'),
#   ('ADJ', 'JJ'),
#   ('AUX', 'MD'),
#   ('PART', 'RB'),
#   ('VERB', 'VB'),
#   ('PRON', 'WP'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('CCONJ', 'CC'),
#   ('PRON', 'DT'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBZ'),
#   ('AUX', 'VBZ'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NN'),
#   ('ADV', 'RB'),
#   ('NOUN', 'NN'),
#   ('PRON', 'DT'),
#   ('AUX', 'VBD'),
#   ('VERB', 'VBN'),
#   ('VERB', 'VBG'),
#   ('NOUN', 'NNS'),
#   ('PART', 'TO'),
#   ('AUX', 'VB'),
#   ('ADJ', 'JJ'),
#   ('PUNCT', 'HYPH'),
#   ('VERB', 'VBN'),
#   ('X', 'XX'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ':'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('CCONJ', 'CC'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '-RRB-'),
#   ('CCONJ', 'CC'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBD'),
#   ('VERB', 'VBG'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PROPN', 'NNP'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('VERB', 'VBG'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('CCONJ', 'CC'),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('PART', 'RB'),
#   ('AUX', 'VB'),
#   ('ADJ', 'JJ'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADV', 'RB'),
#   ('ADJ', 'JJ'),
#   ('SCONJ', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('AUX', 'MD'),
#   ('AUX', 'VB'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '-LRB-'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '-RRB-'),
#   ('X', 'XX'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ':'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '-RRB-'),
#   ('AUX', 'MD'),
#   ('PART', 'RB'),
#   ('PART', 'RB'),
#   ('VERB', 'VB'),
#   ('ADP', 'IN'),
#   ('DET', 'PDT'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('CCONJ', 'CC'),
#   ('DET', 'DT'),
#   ('NOUN', 'NNS'),
#   ('PRON', 'WDT'),
#   ('AUX', 'MD'),
#   ('AUX', 'VB'),
#   ('VERB', 'VBN'),
#   ('INTJ', 'UH'),
#   ('PUNCT', ','),
#   ('AUX', 'MD'),
#   ('PRON', 'PRP'),
#   ('ADV', 'RB'),
#   ('VERB', 'VB'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '.'),
#   ('PART', 'TO'),
#   ('AUX', 'VB'),
#   ('ADJ', 'JJ'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('AUX', 'VB'),
#   ('ADJ', 'JJ'),
#   ('ADV', 'RB'),
#   ('SCONJ', 'IN'),
#   ('NOUN', 'NN'),
#   ('AUX', 'VB'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('CCONJ', 'CC'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NNS'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NNS'),
#   ('PUNCT', ','),
#   ('ADP', 'IN'),
#   ('AUX', 'VBG'),
#   ('VERB', 'VBN'),
#   ('AUX', 'VBZ'),
#   ('PRON', 'EX'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PRON', 'WDT'),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('ADV', 'RB'),
#   ('VERB', 'VB'),
#   ('ADJ', 'JJ'),
#   ('PUNCT', '.'),
#   ('CCONJ', 'CC'),
#   ('SCONJ', 'WRB'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBD'),
#   ('VERB', 'VBN'),
#   ('PUNCT', '-LRB-'),
#   ('AUX', 'MD'),
#   ('PART', 'RB'),
#   ('VERB', 'VB'),
#   ('ADP', 'IN'),
#   ('DET', 'PDT'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADV', 'RB'),
#   ('PUNCT', '-RRB-'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP'),
#   ('PUNCT', '-LRB-'),
#   ('DET', 'PDT'),
#   ('DET', 'DT'),
#   ('NOUN', 'NNS'),
#   ('PRON', 'WDT'),
#   ('AUX', 'MD'),
#   ('AUX', 'VB'),
#   ('VERB', 'VBN'),
#   ('ADV', 'RB'),
#   ('PUNCT', '-RRB-'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NNS'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '-LRB-'),
#   ('AUX', 'MD'),
#   ('PRON', 'PRP'),
#   ('ADV', 'RB'),
#   ('VERB', 'VB'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '.'),
#   ('PUNCT', '-RRB-'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP'),
#   ('PUNCT', '-LRB-'),
#   ('PART', 'TO'),
#   ('AUX', 'VB'),
#   ('ADJ', 'JJ'),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('AUX', 'VB'),
#   ('ADJ', 'JJ'),
#   ('ADV', 'RB'),
#   ('PUNCT', '-RRB-'),
#   ('PUNCT', '-LRB-'),
#   ('SCONJ', 'IN'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('ADP', 'IN'),
#   ('DET', 'PDT'),
#   ('DET', 'DT'),
#   ('NOUN', 'NNS'),
#   ('PUNCT', '-RRB-'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBD'),
#   ('ADJ', 'JJ'),
#   ('ADV', 'RB'),
#   ('PUNCT', '-LRB-'),
#   ('SCONJ', 'IN'),
#   ('NOUN', 'NN'),
#   ('AUX', 'VB'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '-RRB-'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('ADP', 'IN'),
#   ('PUNCT', '-LRB-'),
#   ('CCONJ', 'CC'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NNS'),
#   ('PUNCT', '-RRB-'),
#   ('PUNCT', '-LRB-'),
#   ('CCONJ', 'CC'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NNS'),
#   ('PUNCT', '-RRB-'),
#   ('PUNCT', '-LRB-'),
#   ('ADP', 'IN'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NNS'),
#   ('PUNCT', ','),
#   ('AUX', 'VBG'),
#   ('VERB', 'VBN'),
#   ('PUNCT', '-RRB-'),
#   ('PUNCT', '-LRB-'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NNS'),
#   ('PUNCT', ','),
#   ('ADP', 'IN'),
#   ('AUX', 'VBG'),
#   ('VERB', 'VBN'),
#   ('PUNCT', '-RRB-'),
#   ('CCONJ', 'CC'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('PUNCT', '-LRB-'),
#   ('AUX', 'VBZ'),
#   ('PRON', 'EX'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PRON', 'WDT'),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('ADV', 'RB'),
#   ('VERB', 'VB'),
#   ('ADJ', 'JJ'),
#   ('PUNCT', '.'),
#   ('PUNCT', '-RRB-'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBD'),
#   ('ADV', 'RB'),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('ADV', 'RB'),
#   ('VERB', 'VB'),
#   ('PUNCT', ':'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('CCONJ', 'CC'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '-RRB-'),
#   ('CCONJ', 'CC'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBD'),
#   ('VERB', 'VBG'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NNS'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('VERB', 'VBG'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('CCONJ', 'CC'),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('PART', 'RB'),
#   ('AUX', 'VB'),
#   ('ADJ', 'JJ'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADV', 'RB'),
#   ('ADJ', 'JJ'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('AUX', 'MD'),
#   ('PART', 'RB'),
#   ('AUX', 'VB'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('INTJ', 'UH'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('AUX', 'MD'),
#   ('PART', 'RB'),
#   ('AUX', 'VB'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('NOUN', 'NNS')],
#  [('NOUN', 'NN'),
#   ('PROPN', 'NNP'),
#   ('X', 'LS'),
#   ('PUNCT', '-RRB-'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('SCONJ', 'WRB'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NNS'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('PRON', 'DT'),
#   ('ADP', 'IN'),
#   ('PRON', 'WP'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBZ'),
#   ('CCONJ', 'CC'),
#   ('ADV', 'RB'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('ADV', 'RB'),
#   ('ADV', 'RB'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP'),
#   ('PUNCT', ','),
#   ('DET', 'PDT'),
#   ('DET', 'DT'),
#   ('NOUN', 'NNS'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('VERB', 'VBN'),
#   ('AUX', 'VBZ'),
#   ('ADV', 'RB'),
#   ('NOUN', 'NN'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('VERB', 'VBN'),
#   ('PUNCT', "''"),
#   ('ADV', 'RB'),
#   ('VERB', 'VBD'),
#   ('PRON', 'PRP'),
#   ('PRON', 'DT'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NNS'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBD'),
#   ('VERB', 'VBG'),
#   ('SCONJ', 'WRB'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('VERB', 'VBD'),
#   ('CCONJ', 'CC'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('PART', 'RB'),
#   ('VERB', 'VB'),
#   ('NOUN', 'NN'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('PART', 'RB'),
#   ('VERB', 'VBN'),
#   ('DET', 'DT'),
#   ('ADJ', 'JJ'),
#   ('PRON', 'PRP'),
#   ('CCONJ', 'CC'),
#   ('X', 'XX'),
#   ('X', 'XX'),
#   ('PUNCT', '-RRB-'),
#   ('PRON', 'EX'),
#   ('AUX', 'MD'),
#   ('AUX', 'VB'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP'),
#   ('CCONJ', 'CC'),
#   ('PRON', 'EX'),
#   ('VERB', 'VBD'),
#   ('NOUN', 'NN'),
#   ('SCONJ', 'IN'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP'),
#   ('PRON', 'DT'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NNS'),
#   ('AUX', 'MD'),
#   ('AUX', 'VB'),
#   ('ADJ', 'JJ'),
#   ('PRON', 'EX'),
#   ('VERB', 'VBZ'),
#   ('NOUN', 'NN'),
#   ('X', 'XX'),
#   ('PROPN', 'NNP'),
#   ('ADJ', 'JJ'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '-RRB-'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('CCONJ', 'CC'),
#   ('VERB', 'VB'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NNS'),
#   ('CCONJ', 'CC'),
#   ('VERB', 'VBZ'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('VERB', 'VBN'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NNS'),
#   ('PRON', 'WDT'),
#   ('AUX', 'MD'),
#   ('AUX', 'VB'),
#   ('VERB', 'VBN'),
#   ('PRON', 'PRP'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('PRON', 'DT'),
#   ('ADV', 'RB'),
#   ('CCONJ', 'CC'),
#   ('PRON', 'EX'),
#   ('VERB', 'VBZ'),
#   ('NOUN', 'NN'),
#   ('X', 'XX'),
#   ('NOUN', 'NN'),
#   ('NUM', 'CD'),
#   ('PUNCT', '-RRB-'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('PUNCT', ','),
#   ('SCONJ', 'WRB'),
#   ('AUX', 'VBD'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NN'),
#   ('VERB', 'VB'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '.'),
#   ('SCONJ', 'WRB'),
#   ('AUX', 'VBD'),
#   ('DET', 'PDT'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NNS'),
#   ('VERB', 'VBP'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NNS'),
#   ('VERB', 'VBN'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP$'),
#   ('ADJ', 'JJS'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '.'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('AUX', 'VB'),
#   ('DET', 'DT'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('PRON', 'WP'),
#   ('VERB', 'VBZ'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('ADV', 'RB'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP'),
#   ('INTJ', 'UH'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBD'),
#   ('PART', 'RB'),
#   ('VERB', 'VB'),
#   ('SCONJ', 'IN'),
#   ('INTJ', 'UH'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('PART', 'RB'),
#   ('VERB', 'VB'),
#   ('NOUN', 'NNS'),
#   ('ADP', 'IN'),
#   ('PRON', 'DT'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('PART', 'RB'),
#   ('VERB', 'VBN'),
#   ('DET', 'DT'),
#   ('ADJ', 'JJ'),
#   ('PRON', 'PRP'),
#   ('CCONJ', 'CC'),
#   ('X', 'XX'),
#   ('X', 'XX'),
#   ('PUNCT', '-RRB-'),
#   ('PRON', 'EX'),
#   ('AUX', 'MD'),
#   ('AUX', 'VB'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP'),
#   ('CCONJ', 'CC'),
#   ('PRON', 'EX'),
#   ('VERB', 'VBD'),
#   ('NOUN', 'NN'),
#   ('SCONJ', 'IN'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP'),
#   ('PRON', 'DT'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NNS'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('PRON', 'EX'),
#   ('VERB', 'VBZ'),
#   ('NOUN', 'NN'),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('ADV', 'RB'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '-RRB-'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP$'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('PRON', 'EX'),
#   ('VERB', 'VBZ'),
#   ('DET', 'DT'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('VERB', 'VBN'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NNS'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('PRON', 'DT'),
#   ('ADV', 'RB'),
#   ('CCONJ', 'CC'),
#   ('PRON', 'EX'),
#   ('VERB', 'VBZ'),
#   ('NOUN', 'NN'),
#   ('X', 'XX'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '-RRB-'),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('PART', 'RB'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VB'),
#   ('ADV', 'RB'),
#   ('ADP', 'IN'),
#   ('VERB', 'VBG'),
#   ('PRON', 'PRP'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBZ'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('ADP', 'IN'),
#   ('NUM', 'CD'),
#   ('NOUN', 'NNS'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('CCONJ', 'CC'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP'),
#   ('DET', 'DT'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('ADV', 'RB'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NNS'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('VERB', 'VBZ'),
#   ('PRON', 'PRP'),
#   ('PRON', 'WP'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('SCONJ', 'WRB'),
#   ('DET', 'DT'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('VERB', 'VBZ'),
#   ('PRON', 'PRP'),
#   ('CCONJ', 'CC'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('PRON', 'PRP'),
#   ('ADV', 'RB'),
#   ('X', 'XX'),
#   ('PROPN', 'NNP'),
#   ('NUM', 'CD'),
#   ('PUNCT', '-RRB-'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('SCONJ', 'WRB'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NNS'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('PRON', 'PRP'),
#   ('ADP', 'IN'),
#   ('PRON', 'WP'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBZ'),
#   ('CCONJ', 'CC'),
#   ('ADV', 'RB'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NNS'),
#   ('VERB', 'VBP'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('SCONJ', 'WRB'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('VERB', 'VBG'),
#   ('PRON', 'PRP'),
#   ('DET', 'DT'),
#   ('ADJ', 'JJS'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBD'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('PRON', 'WP'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('ADP', 'IN'),
#   ('PRON', 'DT'),
#   ('PRON', 'DT'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP'),
#   ('ADV', 'RB'),
#   ('AUX', 'VBZ'),
#   ('DET', 'DT'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NN'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('PART', 'RB'),
#   ('VERB', 'VBN'),
#   ('DET', 'DT'),
#   ('ADJ', 'JJ'),
#   ('PRON', 'PRP'),
#   ('ADV', 'RB'),
#   ('CCONJ', 'CC'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('PRON', 'DT'),
#   ('X', 'XX'),
#   ('X', 'XX'),
#   ('PUNCT', '-RRB-'),
#   ('PRON', 'EX'),
#   ('AUX', 'MD'),
#   ('AUX', 'VB'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP'),
#   ('CCONJ', 'CC'),
#   ('PRON', 'EX'),
#   ('VERB', 'VBD'),
#   ('NOUN', 'NN'),
#   ('SCONJ', 'IN'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP'),
#   ('ADV', 'RB'),
#   ('PRON', 'DT'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NNS'),
#   ('AUX', 'MD'),
#   ('AUX', 'VB'),
#   ('ADJ', 'JJ'),
#   ('PRON', 'EX'),
#   ('VERB', 'VBZ'),
#   ('NOUN', 'NN'),
#   ('X', 'XX'),
#   ('PROPN', 'NNP'),
#   ('ADJ', 'JJ'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '-RRB-'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP$'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('PRON', 'EX'),
#   ('VERB', 'VBZ'),
#   ('DET', 'DT'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('VERB', 'VBN'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NNS'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('PRON', 'DT'),
#   ('ADP', 'IN'),
#   ('INTJ', 'UH'),
#   ('PUNCT', ','),
#   ('VERB', 'VBP'),
#   ('PRON', 'PRP'),
#   ('PRON', 'DT'),
#   ('ADP', 'IN'),
#   ('VERB', 'VBP'),
#   ('PRON', 'PRP'),
#   ('PRON', 'DT'),
#   ('ADV', 'RB'),
#   ('CCONJ', 'CC'),
#   ('PRON', 'EX'),
#   ('VERB', 'VBZ'),
#   ('VERB', 'VBN')],
#  [('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('NOUN', 'NN'),
#   ('X', 'LS'),
#   ('PUNCT', '-RRB-'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('CCONJ', 'CC'),
#   ('VERB', 'VBP'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBG'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('ADJ', 'JJ'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('CCONJ', 'CC'),
#   ('VERB', 'VBP'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBG'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NNS'),
#   ('VERB', 'VBN'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('CCONJ', 'CC'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('PRON', 'NN'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('CCONJ', 'CC'),
#   ('AUX', 'VBP'),
#   ('PART', 'RB'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VB'),
#   ('ADV', 'RB'),
#   ('ADV', 'RB'),
#   ('ADJ', 'JJR'),
#   ('CCONJ', 'CC'),
#   ('ADJ', 'JJR'),
#   ('PUNCT', ','),
#   ('CCONJ', 'CC'),
#   ('PRON', 'PRP'),
#   ('X', 'XX'),
#   ('NOUN', 'NN'),
#   ('NUM', 'CD'),
#   ('PUNCT', '-RRB-'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('SCONJ', 'IN'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('ADV', 'RB'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP$'),
#   ('ADJ', 'JJS'),
#   ('NOUN', 'NNS'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PROPN', 'NNP'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('CCONJ', 'CC'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('SCONJ', 'IN'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBZ'),
#   ('PRON', 'DT'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('ADV', 'RB'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('VERB', 'VBN'),
#   ('PRON', 'PRP'),
#   ('ADJ', 'JJ'),
#   ('ADV', 'RB'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('AUX', 'MD'),
#   ('AUX', 'VB'),
#   ('VERB', 'VBN'),
#   ('CCONJ', 'CC'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('PRON', 'PRP'),
#   ('X', 'XX'),
#   ('NOUN', 'NN'),
#   ('NUM', 'CD'),
#   ('PUNCT', '-RRB-'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('PRON', 'PRP'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NN'),
#   ('PART', 'POS'),
#   ('NOUN', 'NN'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NNS'),
#   ('PRON', 'DT'),
#   ('ADP', 'IN'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('CCONJ', 'CC'),
#   ('ADJ', 'JJ'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('NOUN', 'NNS'),
#   ('SCONJ', 'IN'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('CCONJ', 'CC'),
#   ('NOUN', 'NN'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('ADV', 'RB'),
#   ('ADV', 'RB'),
#   ('ADJ', 'JJR'),
#   ('CCONJ', 'CC'),
#   ('ADJ', 'JJR'),
#   ('CCONJ', 'CC'),
#   ('PRON', 'PRP'),
#   ('X', 'XX'),
#   ('NOUN', 'NN'),
#   ('NUM', 'CD'),
#   ('PUNCT', '-RRB-'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('SCONJ', 'IN'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('ADV', 'RB'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP$'),
#   ('ADJ', 'JJS'),
#   ('NOUN', 'NNS'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PROPN', 'NNP'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('CCONJ', 'CC'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('SCONJ', 'IN'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBZ'),
#   ('PRON', 'DT'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('ADV', 'RB'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('VERB', 'VBN'),
#   ('PRON', 'PRP'),
#   ('ADJ', 'JJ'),
#   ('ADV', 'RB'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('AUX', 'MD'),
#   ('AUX', 'VB'),
#   ('VERB', 'VBN'),
#   ('CCONJ', 'CC'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('PRON', 'PRP'),
#   ('X', 'XX'),
#   ('X', 'XX'),
#   ('X', 'XX'),
#   ('SCONJ', 'IN'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBD'),
#   ('ADP', 'RP'),
#   ('VERB', 'VBG'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NNS'),
#   ('PUNCT', ','),
#   ('SCONJ', 'WRB'),
#   ('AUX', 'VBD'),
#   ('PRON', 'PRP'),
#   ('PUNCT', '.'),
#   ('SCONJ', 'WRB'),
#   ('AUX', 'VBZ'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PRON', 'WP'),
#   ('AUX', 'MD'),
#   ('VERB', 'VB'),
#   ('NOUN', 'NNS'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP$'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '.'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('PRON', 'PRP'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('ADV', 'RB'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('VERB', 'VBG'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NNS'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('VERB', 'VBG'),
#   ('NOUN', 'NNS'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADV', 'RB'),
#   ('VERB', 'VBG'),
#   ('ADP', 'RP'),
#   ('ADV', 'RB'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('CCONJ', 'CC'),
#   ('NOUN', 'NN'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('ADJ', 'JJ'),
#   ('PUNCT', ','),
#   ('CCONJ', 'CC'),
#   ('PRON', 'WP'),
#   ('AUX', 'MD'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VB'),
#   ('SCONJ', 'IN'),
#   ('PRON', 'PRP'),
#   ('AUX', 'XX'),
#   ('NOUN', 'NN'),
#   ('NUM', 'CD'),
#   ('PUNCT', '-RRB-'),
#   ('VERB', 'VB'),
#   ('ADJ', 'JJ'),
#   ('CCONJ', 'CC'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NNS'),
#   ('VERB', 'VBD'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP'),
#   ('CCONJ', 'CC'),
#   ('VERB', 'VBD'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VB'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP'),
#   ('PUNCT', ','),
#   ('ADV', 'RB'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('PRON', 'PRP'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('SCONJ', 'IN'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBZ'),
#   ('PRON', 'DT'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('ADV', 'RB'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('VERB', 'VBN'),
#   ('PRON', 'PRP'),
#   ('ADJ', 'JJ'),
#   ('ADV', 'RB'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('AUX', 'MD'),
#   ('AUX', 'VB'),
#   ('VERB', 'VBN'),
#   ('CCONJ', 'CC'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('PRON', 'PRP'),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('ADV', 'RB'),
#   ('VERB', 'VB'),
#   ('X', 'XX'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('CCONJ', 'CC'),
#   ('VERB', 'VB'),
#   ('PUNCT', 'NFP')],
#  [('VERB', 'VB'),
#   ('PROPN', 'NNP'),
#   ('X', 'LS'),
#   ('PUNCT', '-RRB-'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('SCONJ', 'WRB'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('VERB', 'VBD'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADJ', 'JJ'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('CCONJ', 'CC'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('ADP', 'RP'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('CCONJ', 'CC'),
#   ('SCONJ', 'IN'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBD'),
#   ('DET', 'DT'),
#   ('ADJ', 'JJ'),
#   ('PUNCT', 'HYPH'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NN'),
#   ('PRON', 'PRP'),
#   ('ADV', 'RB'),
#   ('AUX', 'MD'),
#   ('AUX', 'VB'),
#   ('VERB', 'VBN'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('VERB', 'VBN'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('X', 'XX'),
#   ('X', 'XX'),
#   ('PUNCT', '-RRB-'),
#   ('PRON', 'DT'),
#   ('ADV', 'RBR'),
#   ('PRON', 'WDT'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('PUNCT', ','),
#   ('PRON', 'DT'),
#   ('ADV', 'RBR'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('SCONJ', 'WRB'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('VERB', 'VBG'),
#   ('SCONJ', 'IN'),
#   ('PRON', 'PRP'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PROPN', 'NNP'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NNS'),
#   ('PUNCT', ','),
#   ('PRON', 'DT'),
#   ('AUX', 'VBZ'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('X', 'XX'),
#   ('PROPN', 'NNP'),
#   ('NUM', 'CD'),
#   ('PUNCT', '-RRB-'),
#   ('NOUN', 'NN'),
#   ('AUX', 'VBD'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('CCONJ', 'CC'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('ADV', 'RB'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PROPN', 'NNP'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('X', 'FW'),
#   ('PUNCT', "''"),
#   ('ADP', 'IN'),
#   ('SCONJ', 'IN'),
#   ('SCONJ', 'IN'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBD'),
#   ('DET', 'DT'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('SCONJ', 'IN'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBD'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('CCONJ', 'CC'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NN'),
#   ('CCONJ', 'CC'),
#   ('PRON', 'EX'),
#   ('VERB', 'VBD'),
#   ('NUM', 'CD'),
#   ('NOUN', 'NN'),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('VERB', 'VB'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('X', 'XX'),
#   ('X', 'XX'),
#   ('PUNCT', '-RRB-'),
#   ('PRON', 'DT'),
#   ('ADV', 'RBR'),
#   ('PRON', 'WDT'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('PUNCT', ','),
#   ('PRON', 'DT'),
#   ('ADV', 'RBR'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('SCONJ', 'WRB'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('VERB', 'VBG'),
#   ('SCONJ', 'IN'),
#   ('PRON', 'PRP'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PROPN', 'NNP'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NNS'),
#   ('PUNCT', ','),
#   ('PRON', 'DT'),
#   ('AUX', 'VBZ'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('SCONJ', 'IN'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('AUX', 'MD'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('ADV', 'RB'),
#   ('ADV', 'RB'),
#   ('ADV', 'RB'),
#   ('AUX', 'VBZ'),
#   ('ADJ', 'JJ'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('VERB', 'VBG'),
#   ('SCONJ', 'IN'),
#   ('PRON', 'PRP'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PROPN', 'NNP'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NNS'),
#   ('PUNCT', ','),
#   ('PRON', 'DT'),
#   ('AUX', 'VBZ'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '-LRB-'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '-RRB-'),
#   ('PROPN', 'NNP'),
#   ('AUX', 'VBD'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('CCONJ', 'CC'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('ADV', 'RB'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('PRON', 'PRP'),
#   ('ADP', 'RP'),
#   ('NOUN', 'NN'),
#   ('CCONJ', 'CC'),
#   ('NOUN', 'NN'),
#   ('ADV', 'RB'),
#   ('PROPN', 'NNP'),
#   ('AUX', 'VBD'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('CCONJ', 'CC'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('ADV', 'RB'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('CCONJ', 'CC'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('ADV', 'RB'),
#   ('ADJ', 'JJR'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NNS'),
#   ('NOUN', 'NNS'),
#   ('NOUN', 'NN'),
#   ('X', 'XX'),
#   ('NOUN', 'NN'),
#   ('NUM', 'CD'),
#   ('PUNCT', '-RRB-'),
#   ('VERB', 'VB'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('CCONJ', 'CC'),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('ADP', 'IN'),
#   ('ADJ', 'JJ'),
#   ('VERB', 'VBP'),
#   ('PRON', 'PRP'),
#   ('DET', 'DT'),
#   ('NOUN', 'NNS'),
#   ('SCONJ', 'WRB'),
#   ('DET', 'DT'),
#   ('NOUN', 'NNS'),
#   ('VERB', 'VBD'),
#   ('PRON', 'PRP'),
#   ('NOUN', 'NNS'),
#   ('ADV', 'RB'),
#   ('PRON', 'DT'),
#   ('AUX', 'VBZ'),
#   ('DET', 'DT'),
#   ('ADJ', 'JJ'),
#   ('PUNCT', 'HYPH'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NN'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('AUX', 'VB'),
#   ('VERB', 'VBN'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PUNCT', 'HYPH'),
#   ('CCONJ', 'CC'),
#   ('PUNCT', 'HYPH'),
#   ('NOUN', 'NN'),
#   ('AUX', 'VBD'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NN'),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('ADV', 'RB'),
#   ('VERB', 'VB'),
#   ('PUNCT', '-RRB-'),
#   ('PRON', 'DT'),
#   ('ADV', 'RBR'),
#   ('PRON', 'WDT'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('PUNCT', ','),
#   ('PRON', 'DT'),
#   ('ADV', 'RBR'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('SCONJ', 'WRB'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('VERB', 'VBG'),
#   ('SCONJ', 'IN'),
#   ('PRON', 'PRP'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PROPN', 'NNP'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NNS'),
#   ('PUNCT', ','),
#   ('PRON', 'DT'),
#   ('AUX', 'VBZ'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('SCONJ', 'IN'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('AUX', 'MD'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('ADV', 'RB'),
#   ('ADV', 'RB'),
#   ('ADV', 'RB'),
#   ('AUX', 'VBZ'),
#   ('ADJ', 'JJ'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('VERB', 'VBG'),
#   ('SCONJ', 'IN'),
#   ('PRON', 'PRP'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PROPN', 'NNP'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NNS'),
#   ('PUNCT', ','),
#   ('PRON', 'DT'),
#   ('AUX', 'VBZ'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PRON', 'DT'),
#   ('ADJ', 'JJR'),
#   ('PRON', 'WDT'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('PUNCT', ','),
#   ('PRON', 'DT'),
#   ('ADV', 'RBR'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('SCONJ', 'WRB'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('VERB', 'VBG'),
#   ('SCONJ', 'IN'),
#   ('PRON', 'PRP'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PROPN', 'NNP'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NNS'),
#   ('PUNCT', ','),
#   ('PRON', 'DT'),
#   ('AUX', 'VBZ'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('SCONJ', 'IN'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('AUX', 'MD'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('ADV', 'RB'),
#   ('ADV', 'RB'),
#   ('ADV', 'RB'),
#   ('AUX', 'VBZ'),
#   ('ADJ', 'JJ'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('VERB', 'VBG'),
#   ('SCONJ', 'IN'),
#   ('PRON', 'PRP'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PROPN', 'NNP'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NNS'),
#   ('PUNCT', ','),
#   ('PRON', 'DT'),
#   ('AUX', 'VBZ'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('X', 'XX'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '-RRB-'),
#   ('INTJ', 'UH'),
#   ('PUNCT', ','),
#   ('PRON', 'DT'),
#   ('AUX', 'VBZ'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PRON', 'DT'),
#   ('AUX', 'VBZ'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('INTJ', 'UH'),
#   ('PUNCT', ','),
#   ('PRON', 'DT'),
#   ('AUX', 'VBZ'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PUNCT', 'HYPH'),
#   ('CCONJ', 'CC'),
#   ('PUNCT', 'HYPH'),
#   ('NOUN', 'NN'),
#   ('AUX', 'VBD'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NN'),
#   ('PRON', 'DT'),
#   ('AUX', 'VBZ'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('INTJ', 'UH'),
#   ('PUNCT', ','),
#   ('PRON', 'DT'),
#   ('AUX', 'VBZ'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('VERB', 'VBG'),
#   ('SCONJ', 'IN'),
#   ('PRON', 'PRP'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PROPN', 'NNP'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NNS'),
#   ('PUNCT', ','),
#   ('PRON', 'DT'),
#   ('AUX', 'VBZ'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN')],
#  [('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('X', 'LS'),
#   ('PUNCT', '-RRB-'),
#   ('ADV', 'RB'),
#   ('AUX', 'VB'),
#   ('ADV', 'RB'),
#   ('ADV', 'RB'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('PART', 'TO'),
#   ('AUX', 'VB'),
#   ('ADJ', 'JJ'),
#   ('ADV', 'RB'),
#   ('AUX', 'VB'),
#   ('ADV', 'RB'),
#   ('ADJ', 'JJ'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('PART', 'TO'),
#   ('AUX', 'VB'),
#   ('ADJ', 'JJ'),
#   ('X', 'XX'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '-RRB-'),
#   ('CCONJ', 'CC'),
#   ('SCONJ', 'IN'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBD'),
#   ('PART', 'RB'),
#   ('VERB', 'VB'),
#   ('ADV', 'RBR'),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBD'),
#   ('VERB', 'VBG'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP'),
#   ('ADV', 'RB'),
#   ('SCONJ', 'IN'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBD'),
#   ('PART', 'RB'),
#   ('VERB', 'VB'),
#   ('ADV', 'RBR'),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBD'),
#   ('ADV', 'RB'),
#   ('ADV', 'RB'),
#   ('X', 'XX'),
#   ('X', 'XX'),
#   ('PUNCT', '-RRB-'),
#   ('PRON', 'WP'),
#   ('VERB', 'VBD'),
#   ('AUX', 'VBD'),
#   ('PART', 'RB'),
#   ('VERB', 'VB'),
#   ('ADJ', 'JJ'),
#   ('PRON', 'WP'),
#   ('VERB', 'VBD'),
#   ('AUX', 'VBD'),
#   ('PART', 'RB'),
#   ('VERB', 'VB'),
#   ('ADJ', 'JJ'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('ADJ', 'JJ'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('ADJ', 'JJ'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PRON', 'WP'),
#   ('VERB', 'VBD'),
#   ('AUX', 'VBD'),
#   ('PART', 'RB'),
#   ('VERB', 'VB'),
#   ('ADJ', 'JJ'),
#   ('PRON', 'WP'),
#   ('VERB', 'VBD'),
#   ('AUX', 'VBD'),
#   ('PART', 'RB'),
#   ('VERB', 'VB'),
#   ('ADJ', 'JJ'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('ADJ', 'JJ'),
#   ('PUNCT', ','),
#   ('ADV', 'RB'),
#   ('ADJ', 'JJ'),
#   ('X', 'XX'),
#   ('NOUN', 'NN'),
#   ('NUM', 'CD'),
#   ('PUNCT', '-RRB-'),
#   ('ADV', 'RB'),
#   ('AUX', 'VB'),
#   ('ADV', 'RB'),
#   ('ADJ', 'JJ'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PROPN', 'NNP'),
#   ('VERB', 'VBP'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('PART', 'TO'),
#   ('AUX', 'VB'),
#   ('ADJ', 'JJ'),
#   ('X', 'XX'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '-RRB-'),
#   ('CCONJ', 'CC'),
#   ('SCONJ', 'IN'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBD'),
#   ('PART', 'RB'),
#   ('VERB', 'VB'),
#   ('ADV', 'RBR'),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBD'),
#   ('VERB', 'VBG'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP'),
#   ('ADV', 'RB'),
#   ('SCONJ', 'IN'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBD'),
#   ('PART', 'RB'),
#   ('VERB', 'VB'),
#   ('ADV', 'RBR'),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBD'),
#   ('ADV', 'RB'),
#   ('ADV', 'RB'),
#   ('X', 'XX'),
#   ('X', 'XX'),
#   ('PUNCT', '-RRB-'),
#   ('PRON', 'WP'),
#   ('VERB', 'VBD'),
#   ('AUX', 'VBD'),
#   ('PART', 'RB'),
#   ('VERB', 'VB'),
#   ('ADJ', 'JJ'),
#   ('PRON', 'WP'),
#   ('VERB', 'VBD'),
#   ('AUX', 'VBD'),
#   ('PART', 'RB'),
#   ('VERB', 'VB'),
#   ('ADJ', 'JJ'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('ADJ', 'JJ'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('ADJ', 'JJ'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PRON', 'WP'),
#   ('VERB', 'VBD'),
#   ('AUX', 'VBD'),
#   ('PART', 'RB'),
#   ('VERB', 'VB'),
#   ('ADJ', 'JJ'),
#   ('PRON', 'WP'),
#   ('VERB', 'VBD'),
#   ('AUX', 'VBD'),
#   ('PART', 'RB'),
#   ('VERB', 'VB'),
#   ('ADJ', 'JJ'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('ADJ', 'JJ'),
#   ('PUNCT', ','),
#   ('ADV', 'RB'),
#   ('ADJ', 'JJ'),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('ADV', 'RB'),
#   ('VERB', 'VB'),
#   ('X', 'XX'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NN'),
#   ('PRON', 'WDT'),
#   ('VERB', 'VBZ'),
#   ('PRON', 'PRP'),
#   ('ADP', 'RP'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NNS'),
#   ('ADV', 'RB'),
#   ('ADV', 'RB'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NNS'),
#   ('CCONJ', 'CC'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NNS'),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('ADV', 'RB'),
#   ('VERB', 'VB'),
#   ('ADV', 'RB'),
#   ('SCONJ', 'WRB'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NNS'),
#   ('AUX', 'MD'),
#   ('VERB', 'VB'),
#   ('CCONJ', 'CC'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('DET', 'DT'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('ADV', 'RB'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('VERB', 'VBP'),
#   ('ADV', 'RB'),
#   ('CCONJ', 'CC'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NNS'),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('AUX', 'VB'),
#   ('VERB', 'VBN'),
#   ('PRON', 'PRP'),
#   ('NOUN', 'NNS'),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('AUX', 'VB'),
#   ('VERB', 'VBN'),
#   ('PRON', 'PRP'),
#   ('SCONJ', 'WRB'),
#   ('PART', 'TO'),
#   ('AUX', 'VB'),
#   ('VERB', 'VBN'),
#   ('PRON', 'PRP'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('ADP', 'RP'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('AUX', 'VB'),
#   ('VERB', 'VBN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NN'),
#   ('SCONJ', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('AUX', 'VB'),
#   ('VERB', 'VBN'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBN'),
#   ('SCONJ', 'IN'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PROPN', 'NNP'),
#   ('DET', 'PDT'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NNS'),
#   ('ADP', 'IN'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NNS'),
#   ('CCONJ', 'CC'),
#   ('SCONJ', 'WRB'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('PRON', 'PRP'),
#   ('PRON', 'DT'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP'),
#   ('X', 'XX'),
#   ('X', 'XX'),
#   ('PUNCT', '-RRB-'),
#   ('PRON', 'WP'),
#   ('VERB', 'VBD'),
#   ('AUX', 'VBD'),
#   ('PART', 'RB'),
#   ('VERB', 'VB'),
#   ('ADJ', 'JJ'),
#   ('PRON', 'WP'),
#   ('VERB', 'VBD'),
#   ('AUX', 'VBD'),
#   ('PART', 'RB'),
#   ('VERB', 'VB'),
#   ('ADJ', 'JJ'),
# ...
#   ('PRON', 'PRP'),
#   ('AUX', 'VBD'),
#   ('PART', 'RB'),
#   ('NOUN', 'NN'),
#   ('PUNCT', "''"),
#   ('ADP', 'IN'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD')],
#  [('NOUN', 'NN'),
#   ('NOUN', 'NNS'),
#   ('NOUN', 'NN'),
#   ('X', 'LS'),
#   ('PUNCT', '-RRB-'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADV', 'RB'),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('VERB', 'VB'),
#   ('ADV', 'RB'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('ADJ', 'JJ'),
#   ('VERB', 'VBG'),
#   ('NOUN', 'NNS'),
#   ('CCONJ', 'CC'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NNS'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('PART', 'RB'),
#   ('ADJ', 'JJ'),
#   ('PRON', 'WDT'),
#   ('AUX', 'VBZ'),
#   ('ADJ', 'JJR'),
#   ('X', 'XX'),
#   ('X', 'XX'),
#   ('X', 'XX'),
#   ('SCONJ', 'IN'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('SCONJ', 'IN'),
#   ('VERB', 'VBG'),
#   ('VERB', 'VBD'),
#   ('PRON', 'PRP'),
#   ('ADV', 'RB'),
#   ('ADV', 'RB'),
#   ('VERB', 'VBG'),
#   ('PROPN', 'NNP'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PROPN', 'NNP'),
#   ('NOUN', 'NNS'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PART', 'POS'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('AUX', 'VBD'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('PRON', 'PRP'),
#   ('PROPN', 'NNP'),
#   ('NOUN', 'NNS'),
#   ('X', 'XX'),
#   ('NOUN', 'NN'),
#   ('NUM', 'CD'),
#   ('PUNCT', '-RRB-'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('PART', 'RB'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('VERB', 'VBD'),
#   ('ADP', 'RP'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADV', 'RB'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('AUX', 'POS'),
#   ('VERB', 'VBG'),
#   ('X', 'XX'),
#   ('X', 'XX'),
#   ('PUNCT', '-RRB-'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('PRON', 'PRP'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NNS'),
#   ('VERB', 'VBD'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NNS'),
#   ('VERB', 'VBD'),
#   ('PRON', 'PRP'),
#   ('PROPN', 'NNP'),
#   ('NOUN', 'NNS'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('ADJ', 'JJ'),
#   ('PROPN', 'NNP'),
#   ('VERB', 'VBD'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NNS'),
#   ('CCONJ', 'CC'),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('PART', 'RB'),
#   ('VERB', 'VB'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PROPN', 'NNP'),
#   ('NOUN', 'NNS'),
#   ('X', 'XX'),
#   ('X', 'XX'),
#   ('PUNCT', '-RRB-'),
#   ('PRON', 'PRP$'),
#   ('PROPN', 'NNP'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('NOUN', 'NN'),
#   ('PROPN', 'NNP'),
#   ('ADJ', 'JJ'),
#   ('CCONJ', 'CC'),
#   ('PRON', 'PRP$'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '``'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('AUX', 'VBD'),
#   ('ADV', 'RB'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PUNCT', "''"),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('PUNCT', '``'),
#   ('INTJ', 'UH'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBZ'),
#   ('VERB', 'VBN'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP'),
#   ('PUNCT', '``'),
#   ('SCONJ', 'WRB'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NNS'),
#   ('AUX', 'VBP'),
#   ('PART', 'RB'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('VERB', 'VB'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADV', 'RB'),
#   ('CCONJ', 'CC'),
#   ('ADV', 'RB'),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('VERB', 'VB'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('DET', 'DT'),
#   ('NOUN', 'NNS'),
#   ('PRON', 'WDT'),
#   ('PRON', 'PRP'),
#   ('ADV', 'RB'),
#   ('VERB', 'VBD'),
#   ('ADP', 'IN'),
#   ('NUM', 'CD'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('NUM', 'CD'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PRON', 'PRP'),
#   ('ADV', 'RB'),
#   ('AUX', 'VBD'),
#   ('ADJ', 'JJ'),
#   ('ADV', 'RB'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VB'),
#   ('ADV', 'RB'),
#   ('PRON', 'PRP'),
#   ('ADV', 'RB'),
#   ('AUX', 'VBP'),
#   ('PART', 'RB'),
#   ('VERB', 'VB'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '``'),
#   ('PROPN', 'NNP'),
#   ('PRON', 'NN'),
#   ('AUX', 'VBZ'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NNS'),
#   ('CCONJ', 'CC'),
#   ('VERB', 'VBZ'),
#   ('PRON', 'PRP'),
#   ('PUNCT', '``'),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('AUX', 'VB'),
#   ('VERB', 'VBN'),
#   ('DET', 'PDT'),
#   ('DET', 'DT'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('PRON', 'WP'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBZ'),
#   ('VERB', 'VBN'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('PUNCT', "''"),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('CCONJ', 'CC'),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('VERB', 'VB'),
#   ('DET', 'DT'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('ADV', 'RB'),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('VERB', 'VB'),
#   ('ADP', 'RP'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PRON', 'WDT'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('ADV', 'RB'),
#   ('VERB', 'VB'),
#   ('PUNCT', '-RRB-'),
#   ('CCONJ', 'CC'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('SCONJ', 'IN'),
#   ('VERB', 'VBG'),
#   ('ADV', 'RB'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBG'),
#   ('PROPN', 'NNP'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NNS'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PART', 'POS'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('PART', 'RB'),
#   ('VERB', 'VB'),
#   ('DET', 'PDT'),
#   ('PRON', 'PRP$'),
#   ('PROPN', 'NNP'),
#   ('NOUN', 'NNS'),
#   ('X', 'XX'),
#   ('X', 'XX'),
#   ('X', 'XX'),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('PART', 'RB'),
#   ('VERB', 'VB'),
#   ('PRON', 'DT'),
#   ('PRON', 'PRP$'),
#   ('PROPN', 'NNP'),
#   ('NOUN', 'NN')],
#  [('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('X', 'LS'),
#   ('PUNCT', ':'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '-RRB-'),
#   ('VERB', 'VBP'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('NUM', 'CD'),
#   ('VERB', 'VBG'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP'),
#   ('CCONJ', 'CC'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('ADV', 'RB'),
#   ('ADV', 'RB'),
#   ('SCONJ', 'IN'),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('PART', 'RB'),
#   ('VERB', 'VB'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP'),
#   ('ADV', 'RB'),
#   ('ADV', 'RB'),
#   ('PRON', 'WP'),
#   ('AUX', 'VBP'),
#   ('PRON', 'PRP'),
#   ('ADJ', 'JJ'),
#   ('ADP', 'IN'),
#   ('PUNCT', '.'),
#   ('CCONJ', 'CC'),
#   ('SCONJ', 'IN'),
#   ('PRON', 'DT'),
#   ('AUX', 'VBZ'),
#   ('DET', 'DT'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('SCONJ', 'WRB'),
#   ('AUX', 'VBD'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VB'),
#   ('ADV', 'RB'),
#   ('ADV', 'RB'),
#   ('ADV', 'RB'),
#   ('PUNCT', '.'),
#   ('AUX', 'VBD'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('PRON', 'NN'),
#   ('ADJ', 'JJ'),
#   ('PUNCT', '.'),
#   ('AUX', 'VBD'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('PUNCT', '.'),
#   ('X', 'XX'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ':'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '-RRB-'),
#   ('CCONJ', 'CC'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('VERB', 'VBG'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('SCONJ', 'WRB'),
#   ('AUX', 'VBD'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('VERB', 'VB'),
#   ('PUNCT', '.'),
#   ('DET', 'DT'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NNS'),
#   ('PUNCT', ','),
#   ('DET', 'DT'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NNS'),
#   ('PUNCT', ','),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('VERB', 'VBP'),
#   ('ADJ', 'JJ'),
#   ('ADP', 'IN'),
#   ('PART', 'RB'),
#   ('VERB', 'VBG'),
#   ('PRON', 'PRP'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('X', 'XX'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ':'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '-RRB-'),
#   ('ADP', 'IN'),
#   ('CCONJ', 'CC'),
#   ('ADV', 'RB'),
#   ('PROPN', 'NNP'),
#   ('ADV', 'RB'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NNS'),
#   ('PROPN', 'NNPS'),
#   ('PUNCT', ','),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NNS'),
#   ('CCONJ', 'CC'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBZ'),
#   ('ADJ', 'JJR'),
#   ('CCONJ', 'CC'),
#   ('VERB', 'VB'),
#   ('SCONJ', 'WRB'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('VERB', 'VBZ'),
#   ('ADP', 'RP'),
#   ('X', 'XX'),
#   ('NOUN', 'NN'),
#   ('NUM', 'CD'),
#   ('PUNCT', ':'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '-RRB-'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('VERB', 'VBZ'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PRON', 'WP'),
#   ('AUX', 'VBZ'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NN'),
#   ('SCONJ', 'IN'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('PRON', 'PRP'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '.'),
#   ('CCONJ', 'CC'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBD'),
#   ('ADV', 'RB'),
#   ('ADJ', 'JJ'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('CCONJ', 'CC'),
#   ('AUX', 'VBP'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VB'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PRON', 'WP'),
#   ('VERB', 'VBD'),
#   ('PRON', 'PRP'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('CCONJ', 'CC'),
#   ('VERB', 'VBD'),
#   ('PRON', 'PRP'),
#   ('ADV', 'RB'),
#   ('PUNCT', '.'),
#   ('AUX', 'MD'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('SCONJ', 'WRB'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('ADV', 'RB'),
#   ('ADJ', 'JJ'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('CCONJ', 'CC'),
#   ('ADV', 'RB'),
#   ('ADJ', 'JJ'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('PUNCT', '.'),
#   ('X', 'XX'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ':'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '-RRB-'),
#   ('SCONJ', 'IN'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBD'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBD'),
#   ('DET', 'DT'),
#   ('NUM', 'CD'),
#   ('NOUN', 'NN'),
#   ('PART', 'TO'),
#   ('AUX', 'VB'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PUNCT', 'HYPH'),
#   ('VERB', 'VBN'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NNS'),
#   ('ADJ', 'JJ'),
#   ('ADP', 'IN'),
#   ('PART', 'RB'),
#   ('VERB', 'VBG'),
#   ('PRON', 'PRP'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NN'),
#   ('X', 'XX'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ':'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('CCONJ', 'CC'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '-RRB-'),
#   ('ADP', 'IN'),
#   ('CCONJ', 'CC'),
#   ('ADV', 'RB'),
#   ('PROPN', 'NNP'),
#   ('ADV', 'RB'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NNS'),
#   ('PROPN', 'NNPS'),
#   ('PUNCT', ','),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NNS'),
#   ('CCONJ', 'CC'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBZ'),
#   ('ADJ', 'JJR'),
#   ('CCONJ', 'CC'),
#   ('VERB', 'VB'),
#   ('SCONJ', 'WRB'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('VERB', 'VBZ'),
#   ('ADP', 'RP'),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('ADV', 'RB'),
#   ('VERB', 'VB'),
#   ('PUNCT', ':'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('PRON', 'DT'),
#   ('PUNCT', '-RRB-'),
#   ('AUX', 'VBD'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBG'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP$'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NN'),
#   ('AUX', 'VBD'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBG'),
#   ('DET', 'DT'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '.'),
#   ('AUX', 'VBD'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBG'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('AUX', 'VBD'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP$'),
#   ('ADJ', 'JJS'),
#   ('NOUN', 'NNS'),
#   ('DET', 'DT'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '.'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADV', 'RB'),
#   ('CCONJ', 'CC'),
#   ('SCONJ', 'WRB'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PRON', 'WDT'),
#   ('VERB', 'VBD'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBD'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('CCONJ', 'CC'),
#   ('SCONJ', 'WRB'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('ADP', 'IN'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('SCONJ', 'IN'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '-LRB-'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ':'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('CCONJ', 'CC'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '-RRB-'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('SCONJ', 'WRB'),
#   ('AUX', 'VBD'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('VERB', 'VB'),
#   ('PUNCT', '.'),
#   ('DET', 'DT'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NNS'),
#   ('PUNCT', ','),
#   ('DET', 'DT'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NNS'),
#   ('PUNCT', ','),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('VERB', 'VBP'),
#   ('ADJ', 'JJ'),
#   ('ADP', 'IN'),
#   ('PART', 'RB'),
#   ('VERB', 'VBG'),
#   ('PRON', 'PRP'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('X', 'XX'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ':'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('CCONJ', 'CC'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '-RRB-'),
#   ('ADP', 'IN'),
#   ('CCONJ', 'CC'),
#   ('ADV', 'RB'),
#   ('PROPN', 'NNP'),
#   ('ADV', 'RB'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NNS'),
#   ('PROPN', 'NNPS'),
#   ('PUNCT', ','),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NNS'),
#   ('CCONJ', 'CC'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBZ'),
#   ('ADJ', 'JJR'),
#   ('CCONJ', 'CC'),
#   ('VERB', 'VB'),
#   ('SCONJ', 'WRB'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('VERB', 'VBZ'),
#   ('ADP', 'RP'),
#   ('X', 'XX'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ':'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('CCONJ', 'CC'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '-RRB-'),
#   ('SCONJ', 'WRB'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('VERB', 'VBZ'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PRON', 'WDT'),
#   ('VERB', 'VBD'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBD'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('SCONJ', 'WRB'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('VERB', 'VBZ'),
#   ('ADP', 'RP'),
#   ('CCONJ', 'CC'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('SCONJ', 'IN'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('ADV', 'RB'),
#   ('CCONJ', 'CC'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('ADP', 'IN'),
#   ('PART', 'RB'),
#   ('VERB', 'VBG'),
#   ('PRON', 'PRP'),
#   ('PRON', 'PRP$'),
#   ('PUNCT', ','),
#   ('VERB', 'VBG'),
#   ('PRON', 'PRP'),
#   ('PRON', 'PRP$'),
#   ('VERB', 'VBG'),
#   ('PRON', 'PRP'),
#   ('PRON', 'PRP$'),
#   ('VERB', 'VBD')]]

# %%
spacy.explain("IN")
# Out:
# 'conjunction, subordinating or preposition'

# %%
# Define function to extract proper nouns from Doc object
def extract_proper_nouns(doc):
    return [token.text for token in doc if token.pos_ == 'PROPN']

# Apply function to Doc column and store resulting proper nouns in new column
lyrics['Proper_Nouns'] = lyrics['Doc'].apply(extract_proper_nouns)

# %%
result = list(lyrics.loc[[3, lyrics.index[-1]], 'Proper_Nouns'])

# %%
# Get all NE labels and assign to variable
labels = nlp.get_pipe("ner").labels

# Print each label and its description
for label in labels:
    print(label + ' : ' + spacy.explain(label))
# Out:
# CARDINAL : Numerals that do not fall under another type
# DATE : Absolute or relative dates or periods
# EVENT : Named hurricanes, battles, wars, sports events, etc.
# FAC : Buildings, airports, highways, bridges, etc.
# GPE : Countries, cities, states
# LANGUAGE : Any named language
# LAW : Named documents made into laws.
# LOC : Non-GPE locations, mountain ranges, bodies of water
# MONEY : Monetary values, including unit
# NORP : Nationalities or religious or political groups
# ORDINAL : "first", "second", etc.
# ORG : Companies, agencies, institutions, etc.
# PERCENT : Percentage, including "%"
# PERSON : People, including fictional
# PRODUCT : Objects, vehicles, foods, etc. (not services)
# QUANTITY : Measurements, as of weight or distance
# TIME : Times smaller than a day
# WORK_OF_ART : Titles of books, songs, etc.

# %%
# Define function to extract named entities from doc objects
def extract_named_entities(doc):
    return [ent.label_ for ent in doc.ents]

# Apply function to Doc column and store resulting named entities in new column
lyrics['Named_Entities'] = lyrics['Doc'].apply(extract_named_entities)
lyrics['Named_Entities']
# Out:
# 0     [CARDINAL, DATE, CARDINAL, NORP, DATE, ORG, DA...
# 1     [CARDINAL, PERSON, DATE, DATE, PERSON, PERSON,...
# 2     [CARDINAL, CARDINAL, PERSON, TIME, DATE, CARDI...
# 3     [CARDINAL, CARDINAL, CARDINAL, NORP, CARDINAL,...
# 4     [CARDINAL, PERSON, DATE, CARDINAL, PERSON, PER...
# 5     [CARDINAL, CARDINAL, PERSON, WORK_OF_ART, DATE...
# 6     [CARDINAL, NORP, PERSON, CARDINAL, CARDINAL, D...
# 7     [CARDINAL, PERSON, ORG, PERSON, PERSON, GPE, P...
# 8                  [CARDINAL, CARDINAL, PERSON, PERSON]
# 9     [CARDINAL, PERSON, CARDINAL, CARDINAL, CARDINA...
# 10    [CARDINAL, DATE, ORG, CARDINAL, CARDINAL, DATE...
# 11    [PERSON, CARDINAL, GPE, ORG, CARDINAL, GPE, OR...
# 12             [ORG, ORG, CARDINAL, ORG, CARDINAL, ORG]
# 13    [CARDINAL, ORG, PERSON, LOC, PERSON, PERSON, C...
# 14    [CARDINAL, PERSON, DATE, TIME, PERSON, ORG, DA...
# 15    [CARDINAL, PRODUCT, ORG, CARDINAL, PERSON, ORG...
# 16    [CARDINAL, PERSON, CARDINAL, PERSON, LOC, PERS...
# Name: Named_Entities, dtype: object

# %%
# Define function to extract text tagged with named entities from doc objects
def extract_named_entities(doc):
    return [ent for ent in doc.ents]

# Apply function to Doc column and store resulting text in new column
lyrics['NE_Words'] = lyrics['Doc'].apply(extract_named_entities)
lyrics['NE_Words']
# Out:
# 0     [(1), (the, weekend), (2), (Methodist), (the, ...
# 1     [(1), (Taylor, Swift, ]), (November), (July), ...
# 2     [(1), (2), (Sorry), (midnight), (seven, years)...
# 3                   [(1), (1), (2), (polish), (1), (2)]
# 4     [(1), (Anywhere), (', 90s), (3), (Anywhere), (...
# 5     [(1), (2), (Nevеr), (Pre, -, Chorus), (autumn)...
# 6     [(1), (Tarnished), (Grieving), (2), (3), (Spri...
# 7     [(1), (Dorothea), (Honey), (Pre, -, Chorus), (...
# 8                       [(1), (2), (Staying), (Guilty)]
# 9     [(1), (Dancin), (one), (one), (2), (one), (one...
# 10    [(1), (2, ], Twenty, years), (Post, -, Chorus,...
# 11    [(l​ong, story, short), (1), (Clung), (Post, -...
# 12    [(Eyes), (anticipatin), (1), (anticipatin), (2...
# 13    [(1), (Strangers), (Matches), (Pages), (Pre, -...
# 14    [(1), (Taylor, Swift, ]), (Tuesday), (night), ...
# 15    [(1), (Champagne), (Champagne), (2), (Chorus, ...
# 16    [(1), (Taylor, Swift, ]), (two), (Taylor, Swif...
# Name: NE_Words, dtype: object

# %%
# Extract the first Doc object
doc = lyrics['Doc'][1]

# Visualize named entity tagging in a single paper
displacy.render(doc, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">evermore Lyrics[Verse
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# :
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Taylor Swift]
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  Gray
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     November
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  I've been down since
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     July
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  Motion capture Put me in a bad light I replay my footsteps on each stepping stone Trying to find the one where I went wrong Writing letters Addressed to the fire [Chorus:
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Taylor Swift
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ] And I was catching my breath Staring out an open window
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Catching
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  my death And I couldn't be sure I had a feeling so peculiar That this pain would be for Evermore [Verse
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# :
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Taylor Swift]
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  Hey December Guess I'm feeling unmoored Can't remember What I used to fight for I rewind thе tape, but all it does is pause On thе very moment all was lost Sending signals To be double-crossed [Chorus:
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Taylor Swift &amp; Justin Vernon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ] And I was catching my breath Barefoot in the wildest
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     winter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Catching
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  my death And I couldn't be sure I had a feeling so peculiar That this pain would be for Evermore (Evermore) [Bridge:
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Justin Vernon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Taylor Swift
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ] Can't not think of all the cost And the things that will be lost Oh, can we just get a pause? To be certain, we'll be tall again Whether weather be the frost Or the violence of the dog days I'm on waves, out being tossed Is there a line that I could just go cross? And when I was shipwrecked (Can't think of all the cost now) I thought of you (All the things that will be lost now) In the cracks of light (Can we just get a pause?) I dreamed of you (To be certain we'll be tall again) (If you think of all the costs) It was real enough (Whether weather be the frost) To get me through (Or the violence of
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the dog days
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ) (Or the violence of
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the dog days
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ) (Out on waves, being tossed) (I'm on waves, out being tossed) But I swear (Is there a line that we can just go cross?) You were there You might also like[Chorus:
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Taylor Swift &amp; Justin Vernon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ] And I was catching my breath Floors of a cabin creaking under my step And I couldn't be sure I had a feeling so peculiar This pain wouldn't be for Evermore Evermore Evermore This pain wouldn't be for evermore Evermore53Embed</div></span>

# %%
# Save DataFrame as csv (in Google Drive)
# Use this step only to save  csv to your computer's working directory
lyrics.to_csv('ts-lyrics.csv')
